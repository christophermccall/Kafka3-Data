# %%
import pandas as pd
import json

# %%
df = pd.read_json('archive/small_listen.json', lines=True)

# %%
df.dtypes
# Out:
# artist            object
# song              object
# duration         float64
# ts                 int64
# sessionId          int64
# auth              object
# level             object
# itemInSession      int64
# city              object
# zip                int64
# state             object
# userAgent         object
# lon              float64
# lat              float64
# userId             int64
# lastName          object
# firstName         object
# gender            object
# registration       int64
# dtype: object

# %%
df.head(20)
# Out:
#                            artist  \
# 0                   Avril Lavigne
# 1         Shaggy Featuring Rayvon
# 2                      Joe Budden
# 3                          Eagles
# 4                         Skillet
# 5                        Harmonia
# 6              Desiderii Marginis
# 7                          ZZ Top
# 8                     Evanescence
# 9                    Billy Talent
# 10                  Griffin House
# 11  Thee Silver Mountain Reveries
# 12                 David Lee Roth
# 13      Chick Corea Akoustic Band
# 14                       Tub Ring
# 15                        Midlake
# 16                   LANDA DANIEL
# 17           Francisca Valenzuela
# 18                      The Coral
# 19                       Coldplay
#
#                                                  song   duration  \
# 0                                        I'm With You  222.90240
# 1                                   In The Summertime  237.76608
# ...
